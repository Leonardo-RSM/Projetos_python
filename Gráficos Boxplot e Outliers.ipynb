# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
enem_sp = pd.read_csv('/Users/paull/OneDrive/Área de Trabalho/LEONARDO/python/jupyter/enem_2019_tratado.csv',
                      sep = ',', encoding = 'iso-8859-1')

# %%
import matplotlib.pyplot as plt
plt.boxplot(enem_sp.NOTA_MT)
plt.show()

# %%
sns.boxplot(y='NOTA_MT', data= enem_sp)
# Out:
# <AxesSubplot:ylabel='NOTA_MT'>

# %%
grafico = px.box(enem_sp, y="NOTA_MT")
grafico.show()

# %%
enem_sp.NOTA_MT.quantile(q=0.75)
# Out:
# 617.9

# %%
sem_outliers = enem_sp.loc[enem_sp.NOTA_MT <= 902.9]
sem_outliers = enem_sp.loc[enem_sp.NOTA_MT >= 359.1]

# %%
sns.boxplot(y='NOTA_MT', data = sem_outliers)
# Out:
# <AxesSubplot:ylabel='NOTA_MT'>

# %%
sns.boxplot(y= 'NOTA_LC', data = enem_sp)
# Out:
# <AxesSubplot:ylabel='NOTA_LC'>

# %%
sns.stripplot(x="SEXO", y="NOTA_MT", data=enem_sp,
           )
sns.boxplot(x="SEXO", y="NOTA_MT", data=enem_sp)
# Out:
# <AxesSubplot:xlabel='SEXO', ylabel='NOTA_MT'>
