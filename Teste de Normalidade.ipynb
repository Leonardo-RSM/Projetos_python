# %%
# TESTE DE NORMALIDADE

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib as plt
import scipy.stats as stats
import matplotlib.pyplot as pwt
import statsmodels
from statsmodels.stats.diagnostic import lilliefors

enem_sp = pd.read_csv('/Users/paull/OneDrive/Área de Trabalho/LEONARDO/python/jupyter/enem_2019_tratado.csv',
                     sep = ',', encoding = 'iso-8859-1')

# %%
enem_tupa = enem_sp.loc[enem_sp.NO_MUNICIPIO_RESIDENCIA == 'Tupã']

# %% [markdown]
# TESTES DE NORMALIDADE
#
# Existem testes númerios e testes gráficos:
#
#
# Shapiro-Wilk (limite de 5000 amostras)
#
#
# Kolmogorov_Smirnov
#
#
# Histograma
#
#
# QQplot

# %%
notas = sns.load_dataset("NOTA_REDACAO")
sns.histplot(data=enem_tupa, x="flipper_length_mm")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14324\1553782580.py in <module>
# ----> 1 notas = sns.load_dataset("NOTA_REDACAO")
#       2 sns.histplot(data=enem_tupa, x="flipper_length_mm")
#
# ~\anaconda3\lib\site-packages\seaborn\utils.py in load_dataset(name, cache, data_home, **kws)
#     593         if not os.path.exists(cache_path):
#     594             if name not in get_dataset_names():
# --> 595                 raise ValueError(f"'{name}' is not one of the example datasets.")
#     596             urlretrieve(url, cache_path)
#     597         full_path = cache_path
#
# ValueError: 'NOTA_REDACAO' is not one of the example datasets.

# %%
grafico = sns.histplot(data=enem_tupa, x="NOTA_REDACAO", bins= 100, stat = 'percent', kde = True)

# %%
grafico = sns.histplot(data=enem_sp, x="NOTA_REDACAO", bins= 100, stat = 'percent', kde = True)

# %%
stats.probplot(enem_sp['NOTA_REDACAO'], dist = "norm", plot = pwt)
pwt.title('Normal Q-Q plot')
pwt.show()

# %%
stats.probplot(enem_tupa['NOTA_REDACAO'], dist = "norm", plot = pwt)
pwt.title('Normal Q-Q plot')
pwt.show()

# %%
stats.probplot(enem_tupa['IDADE'], dist = "norm", plot = pwt)
pwt.title('Normal Q-Q plot')
pwt.show()

# %% [markdown]
# TESTE DE SHAPIRO - WILK
#
# Nível de significância de 0,05 ou 5%
# Quando p > 0,05 (distrivuição normal).

# %%
stats.shapiro(enem_sp.NOTA_REDACAO)
# Out:
# C:\Users\paull\anaconda3\lib\site-packages\scipy\stats\_morestats.py:1800: UserWarning: p-value may not be accurate for N > 5000.
#   warnings.warn("p-value may not be accurate for N > 5000.")
# ShapiroResult(statistic=0.9633597135543823, pvalue=0.0)

# %%
stats.shapiro(enem_tupa.NOTA_REDACAO)
# Out:
# ShapiroResult(statistic=0.9733083248138428, pvalue=3.541695647868437e-08)

# %% [markdown]
# para enem_sp o teste de shapiro acaba não funcionando, mas para tupã o teste da bem menor que 0,05 e aparerece como 3*10^-8

# %% [markdown]
# # Teste de Lilliefors (Kolmogorov-smirnov)

# %%
statsmodels.stats.diagnostic.lilliefors(enem_sp.NOTA_REDACAO, dist = 'norm')
# Out:
# (0.0831243667968013, 0.0009999999999998899)
